# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/mosaic24-ps1/sample_submission.csv
# /kaggle/input/mosaic24-ps1/train.csv
# /kaggle/input/mosaic24-ps1/test.csv

# %%
import math
import datetime as dt

from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, r2_score 
from sklearn.metrics import mean_poisson_deviance, mean_gamma_deviance, accuracy_score
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import LSTM, GRU

from itertools import cycle
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# %%
train = pd.read_csv("/kaggle/input/mosaic24-ps1/train.csv")
test = pd.read_csv("/kaggle/input/mosaic24-ps1/test.csv")

# %%
# Pivot the DataFrame
df_closing = train.pivot(index='Date', columns='Company', values=['Close'])

# Flatten the MultiIndex columns
df_closing.columns = ['_'.join(col).strip() for col in df_closing.columns.values]

# Reset index for better structure
df_closing.reset_index(inplace=True)

# Display the result
df_closing.head()
# Out:
#          Date  Close_Company_0  Close_Company_1  Close_Company_2  \
# 0  2033-03-01       161.915062       113.066659        50.094499
# 1  2033-03-05       163.108507       110.561246        49.250071
# 2  2033-03-06       161.716298       109.651386        48.878616
# 3  2033-03-07       148.051907       109.723772        48.670564
# 4  2033-03-08       148.483368       109.118052        47.642654
#
#    Close_Company_3  Close_Company_4  Close_Company_5
# 0        98.811966      8873.173069       135.882546
# 1        96.594597      8794.758109       135.970813
# 2        93.602065      8616.178598       136.070561
# 3        90.718080      8679.165970       135.772818
# 4        90.771456      8729.613528       137.854360

# %%
df_closing_company4 = df_closing[['Date', 'Close_Company_4']]

# %%
df_closing_company4.loc[:, 'Date'] = pd.to_datetime(df_closing_company4['Date'], utc=True)

# %%
from datetime import datetime
import pytz

# Convert the string to a timezone-aware Timestamp object
date_threshold_str = '2033-06-01'
date_threshold = pd.Timestamp(datetime.strptime(date_threshold_str, '%Y-%m-%d'), tz=pytz.UTC)

# Filter the DataFrame based on the condition
stock_df_close_last_1_year = df_closing_company4[df_closing_company4['Date'] > date_threshold]

# Make a copy of the filtered DataFrame
stock_df_close_last_1_year_original_gt = stock_df_close_last_1_year.copy()

# Print the total data for prediction
print("Total data for prediction: ", stock_df_close_last_1_year.shape[0])
# Out:
# Total data for prediction:  1173

# %%
fig = px.line(stock_df_close_last_1_year, x=stock_df_close_last_1_year.Date, y=stock_df_close_last_1_year.Close_Company_4,labels={'Date':'Date','Close_Company_4':'Close_Company_4'})

fig.update_traces(marker_line_width=2, opacity=0.8, marker_line_color='orange')

fig.update_layout(title_text='Considered period to predict Stock close price', plot_bgcolor='white', font_size=15, font_color='black')

fig.update_xaxes(showgrid=False)

fig.update_yaxes(showgrid=False)

fig.show()
# Out:
# <div>                            <div id="921cebe9-20fb-45b0-b2b4-cbddee2432be" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("921cebe9-20fb-45b0-b2b4-cbddee2432be")) {                    Plotly.newPlot(                        "921cebe9-20fb-45b0-b2b4-cbddee2432be",                        [{"hovertemplate":"Date=%{x}\u003cbr\u003eClose_Company_4=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle","line":{"color":"orange","width":2}},"mode":"lines","name":"","showlegend":false,"x":["2033-06-04T00:00:00+00:00","2033-06-05T00:00:00+00:00","2033-06-06T00:00:00+00:00","2033-06-07T00:00:00+00:00","2033-06-08T00:00:00+00:00","2033-06-11T00:00:00+00:00","2033-06-12T00:00:00+00:00","2033-06-13T00:00:00+00:00","2033-06-14T00:00:00+00:00","2033-06-15T00:00:00+00:00","2033-06-18T00:00:00+00:00","2033-06-19T00:00:00+00:00","2033-06-20T00:00:00+00:00","2033-06-21T00:00:00+00:00","2033-06-22T00:00:00+00:00","2033-06-25T00:00:00+00:00","2033-06-26T00:00:00+00:00","2033-06-27T00:00:00+00:00","2033-06-28T00:00:00+00:00","2033-06-29T00:00:00+00:00","2033-07-02T00:00:00+00:00","2033-07-03T00:00:00+00:00","2033-07-04T00:00:00+00:00","2033-07-05T00:00:00+00:00","2033-07-06T00:00:00+00:00","2033-07-09T00:00:00+00:00","2033-07-10T00:00:00+00:00","2033-07-11T00:00:00+00:00","2033-07-12T00:00:00+00:00","2033-07-13T00:00:00+00:00","2033-07-16T00:00:00+00:00","2033-07-17T00:00:00+00:00","2033-07-18T00:00:00+00:00","2033-07-19T00:00:00+00:00","2033-07-20T00:00:00+00:00","2033-07-23T00:00:00+00:00","2033-07-24T00:00:00+00:00","2033-07-25T00:00:00+00:00","2033-07-26T00:00:00+00:00","2033-07-27T00:00:00+00:00","2033-07-30T00:00:00+00:00","2033-07-31T00:00:00+00:00","2033-08-01T00:00:00+00:00","2033-08-02T00:00:00+00:00","2033-08-03T00:00:00+00:00","2033-08-06T00:00:00+00:00","2033-08-07T00:00:00+00:00","2033-08-08T00:00:00+00:00","2033-08-09T00:00:00+00:00","2033-08-10T00:00:00+00:00","2033-08-13T00:00:00+00:00","2033-08-14T00:00:00+00:00","2033-08-16T00:00:00+00:00","2033-08-17T00:00:00+00:00","2033-08-20T00:00:00+00:00","2033-08-21T00:00:00+00:00","2033-08-23T00:00:00+00:00","2033-08-24T00:00:00+00:00","2033-08-27T00:00:00+00:00","2033-08-28T00:00:00+00:00","2033-08-29T00:00:00+00:00","2033-08-30T00:00:00+00:00","2033-08-31T00:00:00+00:00","2033-09-03T00:00:00+00:00","2033-09-04T00:00:00+00:00","2033-09-05T00:00:00+00:00","2033-09-06T00:00:00+00:00","2033-09-07T00:00:00+00:00","2033-09-10T00:00:00+00:00","2033-09-11T00:00:00+00:00","2033-09-12T00:00:00+00:00","2033-09-14T00:00:00+00:00","2033-09-17T00:00:00+00:00","2033-09-18T00:00:00+00:00","2033-09-19T00:00:00+00:00","2033-09-21T00:00:00+00:00","2033-09-24T00:00:00+00:00","2033-09-25T00:00:00+00:00","2033-09-26T00:00:00+00:00","2033-09-27T00:00:00+00:00","2033-09-28T00:00:00+00:00","2033-10-01T00:00:00+00:00","2033-10-03T00:00:00+00:00","2033-10-04T00:00:00+00:00","2033-10-05T00:00:00+00:00","2033-10-08T00:00:00+00:00","2033-10-09T00:00:00+00:00","2033-10-10T00:00:00+00:00","2033-10-11T00:00:00+00:00","2033-10-12T00:00:00+00:00","2033-10-15T00:00:00+00:00","2033-10-16T00:00:00+00:00","2033-10-17T00:00:00+00:00","2033-10-19T00:00:00+00:00","2033-10-22T00:00:00+00:00","2033-10-23T00:00:00+00:00","2033-10-24T00:00:00+00:00","2033-10-25T00:00:00+00:00","2033-10-26T00:00:00+00:00","2033-10-29T00:00:00+00:00","2033-10-30T00:00:00+00:00","2033-10-31T00:00:00+00:00","2033-11-01T00:00:00+00:00","2033-11-02T00:00:00+00:00","2033-11-05T00:00:00+00:00","2033-11-06T00:00:00+00:00","2033-11-07T00:00:00+00:00","2033-11-09T00:00:00+00:00","2033-11-12T00:00:00+00:00","2033-11-13T00:00:00+00:00","2033-11-14T00:00:00+00:00","2033-11-15T00:00:00+00:00","2033-11-16T00:00:00+00:00","2033-11-19T00:00:00+00:00"," ...

# %%
training_size=int(len(stock_df_close_last_1_year)*0.80)

test_size=len(stock_df_close_last_1_year)-training_size

train_data,test_data = stock_df_close_last_1_year[0:training_size], stock_df_close_last_1_year[training_size:len(stock_df_close_last_1_year)]

print("train_data: ", train_data.shape)  # (201, 2)

print("test_data: ", test_data.shape)
# Out:
# train_data:  (938, 2)
# test_data:  (235, 2)

# %%
del train_data['Date']

del test_data['Date']

# %%
scaler=MinMaxScaler(feature_range=(0,1))

train_data=scaler.fit_transform(np.array(train_data).reshape(-1,1))

test_data = scaler.transform(np.array(test_data).reshape(-1,1))

print(train_data.shape)
# Out:
# (938, 1)

# %%
def create_sliding_window(dataset, time_step=200):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
time_step = 200

X_train, y_train = create_sliding_window(train_data, time_step)

X_test, y_test = create_sliding_window(test_data, time_step)

print("X_train: ", X_train.shape)
print("y_train: ", y_train.shape)
print("X_test: ", X_test.shape)
print("y_test", y_test.shape)
# Out:
# X_train:  (737, 200)
# y_train:  (737,)
# X_test:  (34, 200)
# y_test (34,)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)


print("X_train: ", X_train.shape)
print("X_test: ", X_test.shape)
# Out:
# X_train:  (737, 200, 1)
# X_test:  (34, 200, 1)

# %%
model=Sequential()

model.add(GRU(64,return_sequences=True,input_shape=(time_step,1)))

model.add(GRU(32,return_sequences=True))

model.add(GRU(32))

model.add(Dropout(0.20))

model.add(Dense(1))

model.compile(loss='mean_squared_error',optimizer='adam')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.

# %%
history = model.fit(X_train,y_train, validation_data=(X_test,y_test), epochs=400, batch_size=32, verbose=1)
# Out:
# Epoch 1/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.1059 - val_loss: 0.0449
# Epoch 2/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0142 - val_loss: 0.0120
# Epoch 3/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0070 - val_loss: 0.0029
# Epoch 4/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0062 - val_loss: 0.0013
# Epoch 5/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0043 - val_loss: 0.0015
# Epoch 6/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0041 - val_loss: 2.9015e-04
# Epoch 7/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0044 - val_loss: 3.3230e-04
# Epoch 8/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0038 - val_loss: 0.0010
# Epoch 9/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0042 - val_loss: 3.6661e-04
# Epoch 10/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0037 - val_loss: 6.4155e-04
# Epoch 11/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0042 - val_loss: 0.0022
# Epoch 12/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0039 - val_loss: 1.4896e-04
# Epoch 13/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0036 - val_loss: 8.0026e-04
# Epoch 14/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0039 - val_loss: 1.3765e-04
# Epoch 15/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0034 - val_loss: 2.7109e-04
# Epoch 16/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0036 - val_loss: 7.8806e-04
# Epoch 17/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0033 - val_loss: 2.8310e-04
# Epoch 18/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0032 - val_loss: 0.0029
# Epoch 19/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0049 - val_loss: 5.0611e-04
# Epoch 20/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0033 - val_loss: 2.6086e-04
# Epoch 21/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0031 - val_loss: 4.5826e-04
# Epoch 22/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0042 - val_loss: 2.8967e-04
# Epoch 23/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0027 - val_loss: 0.0015
# Epoch 24/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0027 - val_loss: 0.0011
# Epoch 25/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 26/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0032 - val_loss: 0.0020
# Epoch 27/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0032 - val_loss: 2.1701e-04
# Epoch 28/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0028 - val_loss: 1.2729e-04
# Epoch 29/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0032 - val_loss: 1.2202e-04
# Epoch 30/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0028 - val_loss: 0.0018
# Epoch 31/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0027 - val_loss: 4.6120e-04
# Epoch 32/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0023 - val_loss: 0.0012
# Epoch 33/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0023 - val_loss: 0.0017
# Epoch 34/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0027 - val_loss: 0.0021
# Epoch 35/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0039 - val_loss: 0.0011
# Epoch 36/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0019 - val_loss: 3.5553e-04
# Epoch 37/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0025 - val_loss: 1.1851e-04
# Epoch 38/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0023 - val_loss: 3.9785e-04
# Epoch 39/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0021 - val_loss: 1.3170e-04
# Epoch 40/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0023 - val_loss: 5.8042e-04
# Epoch 41/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0028 - val_loss: 1.5211e-04
# Epoch 42/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0025 - val_loss: 2.7560e-04
# Epoch 43/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 44/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0024 - val_loss: 0.0014
# Epoch 45/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0025 - val_loss: 5.5937e-04
# Epoch 46/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0025 - val_loss: 3.5573e-04
# Epoch 47/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0021 - val_loss: 2.0377e-04
# Epoch 48/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0025 - val_loss: 3.4627e-04
# Epoch 49/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0021 - val_loss: 6.2190e-04
# Epoch 50/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0021 - val_loss: 1.9177e-04
# Epoch 51/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0023 - val_loss: 5.8170e-04
# Epoch 52/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 53/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0037 - val_loss: 5.2354e-04
# Epoch 54/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0020 - val_loss: 1.2013e-04
# Epoch 55/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0024 - val_loss: 2.2743e-04
# Epoch 56/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0022 - val_loss: 9.0850e-04
# Epoch 57/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0020 - val_loss: 2.3757e-04
# Epoch 58/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - val_loss: 1.6366e-04
# Epoch 59/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0019 - val_loss: 3.4174e-04
# Epoch 60/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0022 - val_loss: 3.4381e-04
# Epoch 61/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0018 - val_loss: 2.7835e-04
# Epoch 62/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0019 - val_loss: 1.2397e-04
# Epoch 63/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0021 - val_loss: 1.2831e-04
# Epoch 64/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 65/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0021 - val_loss: 3.0938e-04
# Epoch 66/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0020 - val_loss: 3.0477e-04
# Epoch 67/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0019 - val_loss: 1.7885e-04
# Epoch 68/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0020 - val_loss: 3.9549e-04
# Epoch 69/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0019 - val_loss: 2.6303e-04
# Epoch 70/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0020 - val_loss: 1.2672e-04
# Epoch 71/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 72/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0019 - val_loss: 5.9504e-04
# Epoch 73/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0019 - val_loss: 4.2236e-04
# Epoch 74/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016 - val_loss: 8.7770e-04
# Epoch 75/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016 - val_loss: 1.7245e-04
# Epoch 76/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - val_loss: 2.5980e-04
# Epoch 77/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015 - val_loss: 7.4973e-04
# Epoch 78/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016 - val_loss: 1.5870e-04
# Epoch 79/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0018 - val_loss: 2.8340e-04
# Epoch 80/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 81/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 82/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0025 - val_loss: 0.0012
# Epoch 83/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0023 - val_loss: 5.4379e-04
# Epoch 84/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0019 - val_loss: 8.5945e-04
# Epoch 85/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0023 - val_loss: 1.2578e-04
# Epoch 86/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0018 - val_loss: 7.9374e-04
# Epoch 87/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 88/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - val_loss: 2.8939e-04
# Epoch 89/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0019 - val_loss: 7.9015e-04
# Epoch 90/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015 - val_loss: 3.1304e-04
# Epoch 91/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014 - val_loss: 3.4646e-04
# Epoch 92/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015 - val_loss: 1.3430e-04
# Epoch 93/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016 - val_loss: 1.5299e-04
# Epoch 94/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 95/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0028 - val_loss: 7.8810e-04
# Epoch 96/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014 - val_loss: 3.5577e-04
# Epoch 97/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 98/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0019 - val_loss: 3.0061e-04
# Epoch 99/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014 - val_loss: 3.8123e-04
# Epoch 100/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013 - val_loss: 7.3633e-04
# Epoch 101/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014 - val_loss: 8.4404e-04
# Epoch 102/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013 - val_loss: 6.4928e-04
# Epoch 103/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - val_loss: 1.8159e-04
# Epoch 104/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012 - val_loss: 6.0960e-04
# Epoch 105/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 106/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - val_loss: 9.6164e-04
# Epoch 107/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0021 - val_loss: 0.0010
# Epoch 108/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014 - val_loss: 5.4180e-04
# Epoch 109/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - val_loss: 6.5214e-04
# Epoch 110/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0014 - val_loss: 1.2830e-04
# Epoch 111/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - val_loss: 1.9845e-04
# Epoch 112/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0010 - val_loss: 1.3721e-04
# Epoch 113/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012 - val_loss: 3.5308e-04
# Epoch 114/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012 - val_loss: 4.0680e-04
# Epoch 115/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012 - val_loss: 2.2123e-04
# Epoch 116/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - val_loss: 6.0804e-04
# Epoch 117/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012 - val_loss: 5.9348e-04
# Epoch 118/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014 - val_loss: 1.7512e-04
# Epoch 119/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013 - val_loss: 6.2873e-04
# Epoch 120/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014 - val_loss: 1.3002e-04
# Epoch 121/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - val_loss: 1.6213e-04
# Epoch 122/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - val_loss: 1.9921e-04
# Epoch 123/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012 - val_loss: 1.5521e-04
# Epoch 124/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012 - val_loss: 2.3629e-04
# Epoch 125/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - val_loss: 1.6293e-04
# Epoch 126/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0011 - val_loss: 3.8940e-04
# Epoch 127/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014 - val_loss: 1.4486e-04
# Epoch 128/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0010 - val_loss: 2.2400e-04
# Epoch 129/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0010 - val_loss: 8.5164e-04
# Epoch 130/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0014 - val_loss: 5.9640e-04
# Epoch 131/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - val_loss: 1.5658e-04
# Epoch 132/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0011 - val_loss: 3.2687e-04
# Epoch 133/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0011 - val_loss: 1.7004e-04
# Epoch 134/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0011 - val_loss: 1.2938e-04
# Epoch 135/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012 - val_loss: 2.3822e-04
# Epoch 136/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015 - val_loss: 4.4924e-04
# Epoch 137/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 138/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - val_loss: 1.7414e-04
# Epoch 139/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.5994e-04 - val_loss: 2.5711e-04
# Epoch 140/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012 - val_loss: 1.2882e-04
# Epoch 141/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0011 - val_loss: 2.5019e-04
# Epoch 142/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 9.4823e-04 - val_loss: 0.0025
# Epoch 143/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0029 - val_loss: 3.7048e-04
# Epoch 144/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - val_loss: 1.4175e-04
# Epoch 145/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.9234e-04 - val_loss: 1.3344e-04
# Epoch 146/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.5199e-04 - val_loss: 8.5490e-04
# Epoch 147/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0010 - val_loss: 1.6022e-04
# Epoch 148/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.2630e-04 - val_loss: 5.0376e-04
# Epoch 149/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - val_loss: 1.2919e-04
# Epoch 150/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.8211e-04 - val_loss: 1.8550e-04
# Epoch 151/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - val_loss: 2.2510e-04
# Epoch 152/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012 - val_loss: 4.4192e-04
# Epoch 153/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0011 - val_loss: 4.6237e-04
# Epoch 154/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.7313e-04 - val_loss: 3.6680e-04
# Epoch 155/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 9.8170e-04 - val_loss: 2.0977e-04
# Epoch 156/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012 - val_loss: 9.1166e-04
# Epoch 157/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.1997e-04 - val_loss: 3.2060e-04
# Epoch 158/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012 - val_loss: 1.8809e-04
# Epoch 159/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.9839e-04 - val_loss: 5.0152e-04
# Epoch 160/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012 - val_loss: 1.5257e-04
# Epoch 161/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.8097e-04 - val_loss: 0.0016
# Epoch 162/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013 - val_loss: 2.0741e-04
# Epoch 163/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.1516e-04 - val_loss: 1.5754e-04
# Epoch 164/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - val_loss: 1.5116e-04
# Epoch 165/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.7595e-04 - val_loss: 2.8018e-04
# Epoch 166/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.1893e-04 - val_loss: 1.6501e-04
# Epoch 167/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.7245e-04 - val_loss: 1.3601e-04
# Epoch 168/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.3259e-04 - val_loss: 2.2204e-04
# Epoch 169/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0010 - val_loss: 4.8126e-04
# Epoch 170/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.2391e-04 - val_loss: 7.2336e-04
# Epoch 171/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014 - val_loss: 3.0581e-04
# Epoch 172/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.3804e-04 - val_loss: 1.9372e-04
# Epoch 173/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0010 - val_loss: 7.3855e-04
# Epoch 174/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015 - val_loss: 0.0029
# Epoch 175/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013 - val_loss: 1.2478e-04
# Epoch 176/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.2093e-04 - val_loss: 1.2734e-04
# Epoch 177/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.9070e-04 - val_loss: 3.2891e-04
# Epoch 178/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.1597e-04 - val_loss: 2.6531e-04
# Epoch 179/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0010 - val_loss: 2.6225e-04
# Epoch 180/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - val_loss: 2.7922e-04
# Epoch 181/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - val_loss: 2.2697e-04
# Epoch 182/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.0596e-04 - val_loss: 1.8733e-04
# Epoch 183/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.9484e-04 - val_loss: 2.5789e-04
# Epoch 184/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.9012e-04 - val_loss: 5.3598e-04
# Epoch 185/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.9845e-04 - val_loss: 1.3453e-04
# Epoch 186/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.1455e-04 - val_loss: 1.9145e-04
# Epoch 187/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.6724e-04 - val_loss: 1.4635e-04
# Epoch 188/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.4863e-04 - val_loss: 4.2526e-04
# Epoch 189/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014 - val_loss: 1.5100e-04
# Epoch 190/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.2552e-04 - val_loss: 3.1860e-04
# Epoch 191/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - val_loss: 1.4808e-04
# Epoch 192/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.3132e-04 - val_loss: 5.0598e-04
# Epoch 193/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0010 - val_loss: 1.2599e-04
# Epoch 194/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 9.8317e-04 - val_loss: 1.7928e-04
# Epoch 195/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.1781e-04 - val_loss: 1.2161e-04
# Epoch 196/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.1591e-04 - val_loss: 1.2694e-04
# Epoch 197/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - val_loss: 2.4544e-04
# Epoch 198/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.7320e-04 - val_loss: 1.3989e-04
# Epoch 199/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - val_loss: 2.3822e-04
# Epoch 200/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.6613e-04 - val_loss: 5.5937e-04
# Epoch 201/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.3847e-04 - val_loss: 1.3112e-04
# Epoch 202/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.4211e-04 - val_loss: 1.6201e-04
# Epoch 203/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.5359e-04 - val_loss: 1.3535e-04
# Epoch 204/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 8.7116e-04 - val_loss: 3.2480e-04
# Epoch 205/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.3853e-04 - val_loss: 4.7142e-04
# Epoch 206/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.6664e-04 - val_loss: 1.4524e-04
# Epoch 207/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.1817e-04 - val_loss: 3.3150e-04
# Epoch 208/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.7153e-04 - val_loss: 1.2499e-04
# Epoch 209/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.5922e-04 - val_loss: 2.3912e-04
# Epoch 210/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.4799e-04 - val_loss: 4.0904e-04
# Epoch 211/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.7841e-04 - val_loss: 1.3425e-04
# Epoch 212/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013 - val_loss: 1.8695e-04
# Epoch 213/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.9425e-04 - val_loss: 1.9806e-04
# Epoch 214/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.3106e-04 - val_loss: 1.4244e-04
# Epoch 215/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.9880e-04 - val_loss: 1.7149e-04
# Epoch 216/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.8482e-04 - val_loss: 2.9026e-04
# Epoch 217/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.0910e-04 - val_loss: 0.0019
# Epoch 218/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0020 - val_loss: 6.7752e-04
# Epoch 219/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.4338e-04 - val_loss: 3.8913e-04
# Epoch 220/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.7685e-04 - val_loss: 3.0589e-04
# Epoch 221/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.5763e-04 - val_loss: 1.2953e-04
# Epoch 222/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.4023e-04 - val_loss: 1.3235e-04
# Epoch 223/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.1410e-04 - val_loss: 1.6544e-04
# Epoch 224/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 9.0667e-04 - val_loss: 1.2414e-04
# Epoch 225/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.6718e-04 - val_loss: 1.4684e-04
# Epoch 226/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.7746e-04 - val_loss: 8.1974e-04
# Epoch 227/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.4884e-04 - val_loss: 3.2672e-04
# Epoch 228/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.2989e-04 - val_loss: 4.6264e-04
# Epoch 229/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.9536e-04 - val_loss: 1.9550e-04
# Epoch 230/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.3917e-04 - val_loss: 1.5288e-04
# Epoch 231/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.8465e-04 - val_loss: 2.1310e-04
# Epoch 232/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.7484e-04 - val_loss: 2.2789e-04
# Epoch 233/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012 - val_loss: 2.5677e-04
# Epoch 234/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.7331e-04 - val_loss: 3.1431e-04
# Epoch 235/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0014 - val_loss: 2.6523e-04
# Epoch 236/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012 - val_loss: 1.9531e-04
# Epoch 237/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.9040e-04 - val_loss: 4.2461e-04
# Epoch 238/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - val_loss: 1.7622e-04
# Epoch 239/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.4926e-04 - val_loss: 1.4770e-04
# Epoch 240/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.9017e-04 - val_loss: 7.3673e-04
# Epoch 241/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 242/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0011 - val_loss: 5.5862e-04
# Epoch 243/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.4772e-04 - val_loss: 2.8227e-04
# Epoch 244/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.1059e-04 - val_loss: 1.4207e-04
# Epoch 245/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0010 - val_loss: 3.5132e-04
# Epoch 246/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.3201e-04 - val_loss: 1.5750e-04
# Epoch 247/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.3900e-04 - val_loss: 7.4031e-04
# Epoch 248/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0012 - val_loss: 5.4426e-04
# Epoch 249/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0010 - val_loss: 2.3656e-04
# Epoch 250/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.8403e-04 - val_loss: 0.0012
# Epoch 251/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.2302e-04 - val_loss: 1.3274e-04
# Epoch 252/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.9526e-04 - val_loss: 1.2518e-04
# Epoch 253/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.3465e-04 - val_loss: 6.4899e-04
# Epoch 254/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.7087e-04 - val_loss: 3.6366e-04
# Epoch 255/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.7553e-04 - val_loss: 1.9162e-04
# Epoch 256/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0010 - val_loss: 1.8834e-04
# Epoch 257/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013 - val_loss: 5.9478e-04
# Epoch 258/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.3034e-04 - val_loss: 5.3536e-04
# Epoch 259/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.4960e-04 - val_loss: 2.6582e-04
# Epoch 260/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.6244e-04 - val_loss: 9.5668e-04
# Epoch 261/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.7764e-04 - val_loss: 1.3423e-04
# Epoch 262/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.5420e-04 - val_loss: 1.5424e-04
# Epoch 263/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.2099e-04 - val_loss: 3.2653e-04
# Epoch 264/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.6961e-04 - val_loss: 1.2072e-04
# Epoch 265/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.7015e-04 - val_loss: 2.7239e-04
# Epoch 266/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.5025e-04 - val_loss: 1.3844e-04
# Epoch 267/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.3683e-04 - val_loss: 1.2414e-04
# Epoch 268/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.9710e-04 - val_loss: 1.3965e-04
# Epoch 269/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.8878e-04 - val_loss: 1.5899e-04
# Epoch 270/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.4821e-04 - val_loss: 1.2957e-04
# Epoch 271/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.6641e-04 - val_loss: 4.7222e-04
# Epoch 272/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.6934e-04 - val_loss: 2.0777e-04
# Epoch 273/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 9.7945e-04 - val_loss: 1.2367e-04
# Epoch 274/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.0750e-04 - val_loss: 5.0635e-04
# Epoch 275/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.6251e-04 - val_loss: 8.6909e-04
# Epoch 276/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 8.4342e-04 - val_loss: 2.4826e-04
# Epoch 277/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 8.4403e-04 - val_loss: 2.2645e-04
# Epoch 278/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.8185e-04 - val_loss: 1.3392e-04
# Epoch 279/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0010 - val_loss: 3.6017e-04
# Epoch 280/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 9.2434e-04 - val_loss: 4.2983e-04
# Epoch 281/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.8493e-04 - val_loss: 1.3536e-04
# Epoch 282/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.0840e-04 - val_loss: 1.5954e-04
# Epoch 283/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.6801e-04 - val_loss: 2.9091e-04
# Epoch 284/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 9.4212e-04 - val_loss: 5.2431e-04
# Epoch 285/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.1152e-04 - val_loss: 0.0017
# Epoch 286/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015 - val_loss: 2.9729e-04
# Epoch 287/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.0589e-04 - val_loss: 1.2133e-04
# Epoch 288/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0010 - val_loss: 8.1359e-04
# Epoch 289/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.8829e-04 - val_loss: 1.2209e-04
# Epoch 290/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.4769e-04 - val_loss: 3.5709e-04
# Epoch 291/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.4137e-04 - val_loss: 2.6506e-04
# Epoch 292/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.9106e-04 - val_loss: 0.0010
# Epoch 293/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0011 - val_loss: 2.7564e-04
# Epoch 294/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.1024e-04 - val_loss: 2.8066e-04
# Epoch 295/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.2147e-04 - val_loss: 5.4472e-04
# Epoch 296/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.2246e-04 - val_loss: 3.7275e-04
# Epoch 297/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0020 - val_loss: 1.6820e-04
# Epoch 298/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014 - val_loss: 5.0577e-04
# Epoch 299/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.4033e-04 - val_loss: 3.6594e-04
# Epoch 300/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.7402e-04 - val_loss: 1.9777e-04
# Epoch 301/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.0623e-04 - val_loss: 3.2055e-04
# Epoch 302/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.8860e-04 - val_loss: 1.5585e-04
# Epoch 303/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.4196e-04 - val_loss: 1.1945e-04
# Epoch 304/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.6692e-04 - val_loss: 1.5106e-04
# Epoch 305/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.8622e-04 - val_loss: 2.5299e-04
# Epoch 306/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.9086e-04 - val_loss: 1.2530e-04
# Epoch 307/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.8892e-04 - val_loss: 1.3007e-04
# Epoch 308/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.7156e-04 - val_loss: 1.4843e-04
# Epoch 309/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.9002e-04 - val_loss: 2.3845e-04
# Epoch 310/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.6144e-04 - val_loss: 1.2828e-04
# Epoch 311/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - val_loss: 1.3625e-04
# Epoch 312/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.9191e-04 - val_loss: 3.6660e-04
# Epoch 313/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - val_loss: 2.1718e-04
# Epoch 314/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.8461e-04 - val_loss: 0.0016
# Epoch 315/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.3366e-04 - val_loss: 1.2237e-04
# Epoch 316/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.2815e-04 - val_loss: 5.1540e-04
# Epoch 317/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.8918e-04 - val_loss: 9.3903e-04
# Epoch 318/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.6731e-04 - val_loss: 1.2056e-04
# Epoch 319/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.9847e-04 - val_loss: 1.3874e-04
# Epoch 320/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.6722e-04 - val_loss: 1.2651e-04
# Epoch 321/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.4400e-04 - val_loss: 0.0012
# Epoch 322/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - val_loss: 9.0439e-04
# Epoch 323/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.1250e-04 - val_loss: 2.1789e-04
# Epoch 324/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.5092e-04 - val_loss: 4.3345e-04
# Epoch 325/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.2992e-04 - val_loss: 2.5509e-04
# Epoch 326/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.8732e-04 - val_loss: 5.1334e-04
# Epoch 327/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.5099e-04 - val_loss: 1.7748e-04
# Epoch 328/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - val_loss: 3.3071e-04
# Epoch 329/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.5283e-04 - val_loss: 1.5720e-04
# Epoch 330/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.4433e-04 - val_loss: 1.6897e-04
# Epoch 331/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.7481e-04 - val_loss: 1.3705e-04
# Epoch 332/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.0890e-04 - val_loss: 2.6176e-04
# Epoch 333/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 8.5048e-04 - val_loss: 1.1743e-04
# Epoch 334/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.8439e-04 - val_loss: 2.7862e-04
# Epoch 335/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.4647e-04 - val_loss: 2.2242e-04
# Epoch 336/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.7658e-04 - val_loss: 4.0033e-04
# Epoch 337/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.5345e-04 - val_loss: 2.2792e-04
# Epoch 338/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - val_loss: 6.7006e-04
# Epoch 339/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.8064e-04 - val_loss: 1.6844e-04
# Epoch 340/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.5162e-04 - val_loss: 8.9586e-04
# Epoch 341/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.5679e-04 - val_loss: 3.4650e-04
# Epoch 342/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.5942e-04 - val_loss: 2.4973e-04
# Epoch 343/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.0939e-04 - val_loss: 8.4474e-04
# Epoch 344/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.7067e-04 - val_loss: 8.9943e-04
# Epoch 345/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.2263e-04 - val_loss: 1.2729e-04
# Epoch 346/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.0988e-04 - val_loss: 3.7322e-04
# Epoch 347/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.7887e-04 - val_loss: 4.4974e-04
# Epoch 348/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.7197e-04 - val_loss: 1.3758e-04
# Epoch 349/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 8.6231e-04 - val_loss: 0.0011
# Epoch 350/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0011 - val_loss: 1.2451e-04
# Epoch 351/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.4289e-04 - val_loss: 4.0048e-04
# Epoch 352/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.5428e-04 - val_loss: 1.3503e-04
# Epoch 353/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.0736e-04 - val_loss: 3.3327e-04
# Epoch 354/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.1381e-04 - val_loss: 3.9095e-04
# Epoch 355/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.7260e-04 - val_loss: 1.3363e-04
# Epoch 356/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.7724e-04 - val_loss: 9.0746e-04
# Epoch 357/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.8634e-04 - val_loss: 3.7145e-04
# Epoch 358/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.9574e-04 - val_loss: 0.0012
# Epoch 359/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - val_loss: 1.5432e-04
# Epoch 360/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.8247e-04 - val_loss: 1.6926e-04
# Epoch 361/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.3707e-04 - val_loss: 7.4772e-04
# Epoch 362/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - val_loss: 1.7274e-04
# Epoch 363/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0010 - val_loss: 3.4863e-04
# Epoch 364/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.2917e-04 - val_loss: 1.8786e-04
# Epoch 365/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.0064e-04 - val_loss: 1.1616e-04
# Epoch 366/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.5033e-04 - val_loss: 3.3399e-04
# Epoch 367/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.5264e-04 - val_loss: 3.3996e-04
# Epoch 368/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.7347e-04 - val_loss: 1.1348e-04
# Epoch 369/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.9578e-04 - val_loss: 3.7540e-04
# Epoch 370/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.1222e-04 - val_loss: 3.9034e-04
# Epoch 371/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.2622e-04 - val_loss: 3.8051e-04
# Epoch 372/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.3240e-04 - val_loss: 1.4342e-04
# Epoch 373/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.2748e-04 - val_loss: 4.7150e-04
# Epoch 374/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.7760e-04 - val_loss: 1.2789e-04
# Epoch 375/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.7901e-04 - val_loss: 5.2828e-04
# Epoch 376/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.6467e-04 - val_loss: 1.3532e-04
# Epoch 377/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.9463e-04 - val_loss: 1.1851e-04
# Epoch 378/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.6820e-04 - val_loss: 7.6732e-04
# Epoch 379/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.4259e-04 - val_loss: 0.0010
# Epoch 380/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0010 - val_loss: 1.5206e-04
# Epoch 381/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.6679e-04 - val_loss: 1.1976e-04
# Epoch 382/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.9973e-04 - val_loss: 1.8036e-04
# Epoch 383/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.4616e-04 - val_loss: 2.5149e-04
# Epoch 384/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.6335e-04 - val_loss: 0.0011
# Epoch 385/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.9213e-04 - val_loss: 2.6055e-04
# Epoch 386/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.9087e-04 - val_loss: 4.4795e-04
# Epoch 387/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.9721e-04 - val_loss: 4.6470e-04
# Epoch 388/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.7975e-04 - val_loss: 1.1232e-04
# Epoch 389/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.7866e-04 - val_loss: 4.2933e-04
# Epoch 390/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.7104e-04 - val_loss: 1.6512e-04
# Epoch 391/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.3830e-04 - val_loss: 3.3150e-04
# Epoch 392/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.3007e-04 - val_loss: 2.5178e-04
# Epoch 393/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.6250e-04 - val_loss: 1.2782e-04
# Epoch 394/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.4539e-04 - val_loss: 3.7419e-04
# Epoch 395/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.3481e-04 - val_loss: 2.0847e-04
# Epoch 396/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.9325e-04 - val_loss: 9.1174e-04
# Epoch 397/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - val_loss: 1.9079e-04
# Epoch 398/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.6114e-04 - val_loss: 1.1215e-04
# Epoch 399/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0010 - val_loss: 1.5985e-04
# Epoch 400/400
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.0918e-04 - val_loss: 1.7189e-04

# %%
train_predict=model.predict(X_train)

test_predict=model.predict(X_test)

train_predict.shape, test_predict.shape
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# ((737, 1), (34, 1))

# %%
train_predict = scaler.inverse_transform(train_predict)

test_predict = scaler.inverse_transform(test_predict)

original_ytrain = scaler.inverse_transform(y_train.reshape(-1,1)) 

original_ytest = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
print("Train data RMSE: ", math.sqrt(mean_squared_error(original_ytrain, train_predict)))

print("Train data MSE: ", mean_squared_error(original_ytrain,train_predict))

print("Train data MAE: ", mean_absolute_error(original_ytrain,train_predict))

print("-------------------------------------------------------------------------------------")

print("Test data RMSE: ", math.sqrt(mean_squared_error(original_ytest,test_predict)))

print("Test data MSE: ", mean_squared_error(original_ytest,test_predict))

print("Test data MAE: ", mean_absolute_error(original_ytest,test_predict))
# Out:
# Train data RMSE:  148.8657251558449
# Train data MSE:  22161.00412617555
# Train data MAE:  106.63315721808416
# -------------------------------------------------------------------------------------
# Test data RMSE:  84.73873108289156
# Test data MSE:  7180.652545538614
# Test data MAE:  68.40501966931949

# %%
# Reshape test data to use as input for prediction
x_input = test_data[len(test_data) - time_step:]
x_input = (np.array(x_input)).reshape(1,time_step,-1)
print("x_input.shape ", x_input.shape)
# print("x_input", x_input)
print('###########################################################################')

from numpy import array

# Initialize variables
temp_input = list(x_input)
lst_output = []
n_steps = time_step
pred_days = 96  # Predict for 96 days

for _ in range(pred_days):
    if len(temp_input[0]) > time_step:
        x_input = array(temp_input[0][1:])  # Remove the first element from temp_input
        x_input = x_input.reshape((1, n_steps, -1))
        y_pred = model.predict(x_input, verbose=0)
        
        temp_input[0] = np.append(temp_input[0][1:], y_pred)  # Append the predicted value to temp_input
        lst_output.append(y_pred[0].tolist())
    else:
        # Reshape input for prediction if temp_input length is less than time_step
        x_input = array(temp_input[0])
        x_input = x_input.reshape((1, n_steps, -1))
        y_pred = model.predict(x_input, verbose=0)
        
        temp_input[0] = np.append(temp_input[0], y_pred)  # Append the predicted value to temp_input
        lst_output.append(y_pred[0].tolist())

print("Output of predicted next days: ", len(lst_output))
# Out:
# x_input.shape  (1, 200, 1)
# ###########################################################################
# Output of predicted next days:  96

# %%
last_days=np.arange(1,time_step+1)
day_pred=np.arange(time_step+1,time_step+pred_days+1)
temp_matrix = np.empty((len(last_days)+pred_days, 1))

temp_matrix[:] = np.nan

# %%
last_original_days_value = temp_matrix

next_predicted_days_value = temp_matrix

last_original_days_value[0:time_step] = (np.array((stock_df_close_last_1_year_original_gt.iloc[-time_step:]['Close_Company_4']))).reshape(-1,1).tolist()

# Assign values to next_predicted_days_value
next_predicted_days_value[time_step:] = (scaler.inverse_transform(lst_output)).tolist()[0]

# %%
# Convert next_predicted_days_value to a DataFrame
predictions_df = pd.DataFrame(next_predicted_days_value, columns=['Predictions4'])

# Save the DataFrame to a CSV file
predictions_df.to_csv('predictions4.csv', index=False)

# %%
# scaler is your MinMaxScaler object
# Inverse transform lst_output
new_predicted_values = scaler.inverse_transform(np.array(lst_output).reshape(-1, 1))

# Convert predicted_values to a 1D array
new_predicted_values = new_predicted_values.flatten()


# Convert next_predicted_days_value to a DataFrame
new_predictions_df = pd.DataFrame(new_predicted_values, columns=['Predictions4'])

# Save the DataFrame to a CSV file
new_predictions_df.to_csv('newpredictions4.csv', index=False)
