# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/mosaic24-ps1/sample_submission.csv
# /kaggle/input/mosaic24-ps1/train.csv
# /kaggle/input/mosaic24-ps1/test.csv

# %%
import math
import datetime as dt

from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, r2_score 
from sklearn.metrics import mean_poisson_deviance, mean_gamma_deviance, accuracy_score
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import LSTM, GRU

from itertools import cycle
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# %%
train = pd.read_csv("/kaggle/input/mosaic24-ps1/train.csv")
test = pd.read_csv("/kaggle/input/mosaic24-ps1/test.csv")

# %%
# Pivot the DataFrame
df_closing = train.pivot(index='Date', columns='Company', values=['Close'])

# Flatten the MultiIndex columns
df_closing.columns = ['_'.join(col).strip() for col in df_closing.columns.values]

# Reset index for better structure
df_closing.reset_index(inplace=True)

# Display the result
df_closing.head()
# Out:
#          Date  Close_Company_0  Close_Company_1  Close_Company_2  \
# 0  2033-03-01       161.915062       113.066659        50.094499
# 1  2033-03-05       163.108507       110.561246        49.250071
# 2  2033-03-06       161.716298       109.651386        48.878616
# 3  2033-03-07       148.051907       109.723772        48.670564
# 4  2033-03-08       148.483368       109.118052        47.642654
#
#    Close_Company_3  Close_Company_4  Close_Company_5
# 0        98.811966      8873.173069       135.882546
# 1        96.594597      8794.758109       135.970813
# 2        93.602065      8616.178598       136.070561
# 3        90.718080      8679.165970       135.772818
# 4        90.771456      8729.613528       137.854360

# %%
df_closing_company5 = df_closing[['Date', 'Close_Company_5']]

# %%
df_closing_company5.loc[:, 'Date'] = pd.to_datetime(df_closing_company5['Date'], utc=True)

# %%
from datetime import datetime
import pytz

# Convert the string to a timezone-aware Timestamp object
date_threshold_str = '2033-06-01'
date_threshold = pd.Timestamp(datetime.strptime(date_threshold_str, '%Y-%m-%d'), tz=pytz.UTC)

# Filter the DataFrame based on the condition
stock_df_close_last_1_year = df_closing_company5[df_closing_company5['Date'] > date_threshold]

# Make a copy of the filtered DataFrame
stock_df_close_last_1_year_original_gt = stock_df_close_last_1_year.copy()

# Print the total data for prediction
print("Total data for prediction: ", stock_df_close_last_1_year.shape[0])
# Out:
# Total data for prediction:  1173

# %%
fig = px.line(stock_df_close_last_1_year, x=stock_df_close_last_1_year.Date, y=stock_df_close_last_1_year.Close_Company_5,labels={'Date':'Date','Close_Company_5':'Close_Company_5'})

fig.update_traces(marker_line_width=2, opacity=0.8, marker_line_color='orange')

fig.update_layout(title_text='Considered period to predict Stock close price', plot_bgcolor='white', font_size=15, font_color='black')

fig.update_xaxes(showgrid=False)

fig.update_yaxes(showgrid=False)

fig.show()
# Out:
# <div>                            <div id="d9e9f031-5362-4032-be7e-7fe13518fc43" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9e9f031-5362-4032-be7e-7fe13518fc43")) {                    Plotly.newPlot(                        "d9e9f031-5362-4032-be7e-7fe13518fc43",                        [{"hovertemplate":"Date=%{x}\u003cbr\u003eClose_Company_5=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle","line":{"color":"orange","width":2}},"mode":"lines","name":"","showlegend":false,"x":["2033-06-04T00:00:00+00:00","2033-06-05T00:00:00+00:00","2033-06-06T00:00:00+00:00","2033-06-07T00:00:00+00:00","2033-06-08T00:00:00+00:00","2033-06-11T00:00:00+00:00","2033-06-12T00:00:00+00:00","2033-06-13T00:00:00+00:00","2033-06-14T00:00:00+00:00","2033-06-15T00:00:00+00:00","2033-06-18T00:00:00+00:00","2033-06-19T00:00:00+00:00","2033-06-20T00:00:00+00:00","2033-06-21T00:00:00+00:00","2033-06-22T00:00:00+00:00","2033-06-25T00:00:00+00:00","2033-06-26T00:00:00+00:00","2033-06-27T00:00:00+00:00","2033-06-28T00:00:00+00:00","2033-06-29T00:00:00+00:00","2033-07-02T00:00:00+00:00","2033-07-03T00:00:00+00:00","2033-07-04T00:00:00+00:00","2033-07-05T00:00:00+00:00","2033-07-06T00:00:00+00:00","2033-07-09T00:00:00+00:00","2033-07-10T00:00:00+00:00","2033-07-11T00:00:00+00:00","2033-07-12T00:00:00+00:00","2033-07-13T00:00:00+00:00","2033-07-16T00:00:00+00:00","2033-07-17T00:00:00+00:00","2033-07-18T00:00:00+00:00","2033-07-19T00:00:00+00:00","2033-07-20T00:00:00+00:00","2033-07-23T00:00:00+00:00","2033-07-24T00:00:00+00:00","2033-07-25T00:00:00+00:00","2033-07-26T00:00:00+00:00","2033-07-27T00:00:00+00:00","2033-07-30T00:00:00+00:00","2033-07-31T00:00:00+00:00","2033-08-01T00:00:00+00:00","2033-08-02T00:00:00+00:00","2033-08-03T00:00:00+00:00","2033-08-06T00:00:00+00:00","2033-08-07T00:00:00+00:00","2033-08-08T00:00:00+00:00","2033-08-09T00:00:00+00:00","2033-08-10T00:00:00+00:00","2033-08-13T00:00:00+00:00","2033-08-14T00:00:00+00:00","2033-08-16T00:00:00+00:00","2033-08-17T00:00:00+00:00","2033-08-20T00:00:00+00:00","2033-08-21T00:00:00+00:00","2033-08-23T00:00:00+00:00","2033-08-24T00:00:00+00:00","2033-08-27T00:00:00+00:00","2033-08-28T00:00:00+00:00","2033-08-29T00:00:00+00:00","2033-08-30T00:00:00+00:00","2033-08-31T00:00:00+00:00","2033-09-03T00:00:00+00:00","2033-09-04T00:00:00+00:00","2033-09-05T00:00:00+00:00","2033-09-06T00:00:00+00:00","2033-09-07T00:00:00+00:00","2033-09-10T00:00:00+00:00","2033-09-11T00:00:00+00:00","2033-09-12T00:00:00+00:00","2033-09-14T00:00:00+00:00","2033-09-17T00:00:00+00:00","2033-09-18T00:00:00+00:00","2033-09-19T00:00:00+00:00","2033-09-21T00:00:00+00:00","2033-09-24T00:00:00+00:00","2033-09-25T00:00:00+00:00","2033-09-26T00:00:00+00:00","2033-09-27T00:00:00+00:00","2033-09-28T00:00:00+00:00","2033-10-01T00:00:00+00:00","2033-10-03T00:00:00+00:00","2033-10-04T00:00:00+00:00","2033-10-05T00:00:00+00:00","2033-10-08T00:00:00+00:00","2033-10-09T00:00:00+00:00","2033-10-10T00:00:00+00:00","2033-10-11T00:00:00+00:00","2033-10-12T00:00:00+00:00","2033-10-15T00:00:00+00:00","2033-10-16T00:00:00+00:00","2033-10-17T00:00:00+00:00","2033-10-19T00:00:00+00:00","2033-10-22T00:00:00+00:00","2033-10-23T00:00:00+00:00","2033-10-24T00:00:00+00:00","2033-10-25T00:00:00+00:00","2033-10-26T00:00:00+00:00","2033-10-29T00:00:00+00:00","2033-10-30T00:00:00+00:00","2033-10-31T00:00:00+00:00","2033-11-01T00:00:00+00:00","2033-11-02T00:00:00+00:00","2033-11-05T00:00:00+00:00","2033-11-06T00:00:00+00:00","2033-11-07T00:00:00+00:00","2033-11-09T00:00:00+00:00","2033-11-12T00:00:00+00:00","2033-11-13T00:00:00+00:00","2033-11-14T00:00:00+00:00","2033-11-15T00:00:00+00:00","2033-11-16T00:00:00+00:00","2033-11-19T00:00:00+00:00"," ...

# %%
training_size=int(len(stock_df_close_last_1_year)*0.80)

test_size=len(stock_df_close_last_1_year)-training_size

train_data,test_data = stock_df_close_last_1_year[0:training_size], stock_df_close_last_1_year[training_size:len(stock_df_close_last_1_year)]

print("train_data: ", train_data.shape)  # (201, 2)

print("test_data: ", test_data.shape)
# Out:
# train_data:  (938, 2)
# test_data:  (235, 2)

# %%
del train_data['Date']

del test_data['Date']

# %%
scaler=MinMaxScaler(feature_range=(0,1))

train_data=scaler.fit_transform(np.array(train_data).reshape(-1,1))

test_data = scaler.transform(np.array(test_data).reshape(-1,1))

print(train_data.shape)
# Out:
# (938, 1)

# %%
def create_sliding_window(dataset, time_step=200):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
time_step = 200

X_train, y_train = create_sliding_window(train_data, time_step)

X_test, y_test = create_sliding_window(test_data, time_step)

print("X_train: ", X_train.shape)
print("y_train: ", y_train.shape)
print("X_test: ", X_test.shape)
print("y_test", y_test.shape)
# Out:
# X_train:  (737, 200)
# y_train:  (737,)
# X_test:  (34, 200)
# y_test (34,)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)


print("X_train: ", X_train.shape)
print("X_test: ", X_test.shape)
# Out:
# X_train:  (737, 200, 1)
# X_test:  (34, 200, 1)

# %%
model=Sequential()

model.add(GRU(64,return_sequences=True,input_shape=(time_step,1)))

model.add(GRU(32,return_sequences=True))

model.add(GRU(32))

model.add(Dropout(0.20))

model.add(Dense(1))

model.compile(loss='mean_squared_error',optimizer='adam')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.

# %%
history = model.fit(X_train,y_train, validation_data=(X_test,y_test), epochs=200, batch_size=32, verbose=1)
# Out:
# Epoch 1/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.1106 - val_loss: 0.2396
# Epoch 2/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0177 - val_loss: 0.0753
# Epoch 3/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0106 - val_loss: 0.0233
# Epoch 4/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0069 - val_loss: 0.0035
# Epoch 5/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0056 - val_loss: 0.0207
# Epoch 6/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0059 - val_loss: 0.0020
# Epoch 7/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0050 - val_loss: 0.0024
# Epoch 8/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0048 - val_loss: 0.0077
# Epoch 9/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 10/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0046 - val_loss: 7.5013e-04
# Epoch 11/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0048 - val_loss: 0.0168
# Epoch 12/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0046 - val_loss: 0.0150
# Epoch 13/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0045 - val_loss: 0.0091
# Epoch 14/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0043 - val_loss: 0.0036
# Epoch 15/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0065 - val_loss: 0.0035
# Epoch 16/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0035 - val_loss: 0.0017
# Epoch 17/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0039 - val_loss: 6.7759e-04
# Epoch 18/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0039 - val_loss: 0.0066
# Epoch 19/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0038 - val_loss: 0.0146
# Epoch 20/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0039 - val_loss: 0.0047
# Epoch 21/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0035 - val_loss: 0.0183
# Epoch 22/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0059 - val_loss: 0.0018
# Epoch 23/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0041 - val_loss: 6.1623e-04
# Epoch 24/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0035 - val_loss: 0.0124
# Epoch 25/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0032 - val_loss: 0.0103
# Epoch 26/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0036 - val_loss: 0.0100
# Epoch 27/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0038 - val_loss: 0.0052
# Epoch 28/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0037 - val_loss: 6.1813e-04
# Epoch 29/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0029 - val_loss: 0.0047
# Epoch 30/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0028 - val_loss: 0.0034
# Epoch 31/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0036 - val_loss: 0.0045
# Epoch 32/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0030 - val_loss: 7.6942e-04
# Epoch 33/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0040 - val_loss: 0.0028
# Epoch 34/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0033 - val_loss: 0.0126
# Epoch 35/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0038 - val_loss: 0.0027
# Epoch 36/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 37/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0037 - val_loss: 0.0089
# Epoch 38/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0031 - val_loss: 0.0067
# Epoch 39/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0028 - val_loss: 0.0076
# Epoch 40/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 41/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0026 - val_loss: 0.0012
# Epoch 42/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0037 - val_loss: 0.0066
# Epoch 43/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0031 - val_loss: 0.0028
# Epoch 44/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0029 - val_loss: 0.0015
# Epoch 45/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0029 - val_loss: 6.3223e-04
# Epoch 46/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0032 - val_loss: 6.6100e-04
# Epoch 47/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0032 - val_loss: 0.0029
# Epoch 48/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0029 - val_loss: 5.9594e-04
# Epoch 49/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0034 - val_loss: 0.0030
# Epoch 50/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 51/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0024 - val_loss: 0.0049
# Epoch 52/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0034 - val_loss: 6.8010e-04
# Epoch 53/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0025 - val_loss: 0.0039
# Epoch 54/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0024 - val_loss: 0.0072
# Epoch 55/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0029 - val_loss: 0.0019
# Epoch 56/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0027 - val_loss: 0.0015
# Epoch 57/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0028 - val_loss: 9.3868e-04
# Epoch 58/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0028 - val_loss: 0.0036
# Epoch 59/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0028 - val_loss: 7.5788e-04
# Epoch 60/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0036 - val_loss: 6.4241e-04
# Epoch 61/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0041 - val_loss: 0.0089
# Epoch 62/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 63/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0024 - val_loss: 0.0068
# Epoch 64/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0024 - val_loss: 0.0068
# Epoch 65/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0024 - val_loss: 0.0052
# Epoch 66/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0029 - val_loss: 9.1523e-04
# Epoch 67/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0023 - val_loss: 7.6494e-04
# Epoch 68/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0029 - val_loss: 0.0012
# Epoch 69/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0023 - val_loss: 0.0068
# Epoch 70/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0028 - val_loss: 5.5792e-04
# Epoch 71/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 72/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 73/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0023 - val_loss: 0.0053
# Epoch 74/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 75/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 76/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0036 - val_loss: 0.0197
# Epoch 77/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 78/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0023 - val_loss: 0.0051
# Epoch 79/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 80/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0019 - val_loss: 0.0054
# Epoch 81/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0026 - val_loss: 0.0013
# Epoch 82/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 83/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0026 - val_loss: 0.0039
# Epoch 84/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0023 - val_loss: 0.0075
# Epoch 85/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0030 - val_loss: 0.0019
# Epoch 86/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0021 - val_loss: 0.0025
# Epoch 87/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0021 - val_loss: 0.0032
# Epoch 88/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0020 - val_loss: 5.3509e-04
# Epoch 89/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0032 - val_loss: 0.0176
# Epoch 90/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0025 - val_loss: 5.1981e-04
# Epoch 91/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0023 - val_loss: 6.4945e-04
# Epoch 92/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 93/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0025 - val_loss: 0.0033
# Epoch 94/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 95/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0020 - val_loss: 0.0052
# Epoch 96/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0024 - val_loss: 0.0037
# Epoch 97/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 98/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0018 - val_loss: 0.0087
# Epoch 99/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0029 - val_loss: 7.1668e-04
# Epoch 100/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0022 - val_loss: 0.0124
# Epoch 101/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0029 - val_loss: 6.1929e-04
# Epoch 102/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0020 - val_loss: 0.0029
# Epoch 103/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0023 - val_loss: 0.0056
# Epoch 104/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0020 - val_loss: 0.0024
# Epoch 105/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 106/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 107/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 108/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 109/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0023 - val_loss: 6.4121e-04
# Epoch 110/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0020 - val_loss: 0.0143
# Epoch 111/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0028 - val_loss: 0.0014
# Epoch 112/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 113/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0019 - val_loss: 0.0038
# Epoch 114/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0019 - val_loss: 0.0067
# Epoch 115/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0030 - val_loss: 0.0017
# Epoch 116/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0028 - val_loss: 0.0096
# Epoch 117/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0023 - val_loss: 8.9710e-04
# Epoch 118/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 119/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 120/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0023 - val_loss: 0.0063
# Epoch 121/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0022 - val_loss: 5.8445e-04
# Epoch 122/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0018 - val_loss: 8.1038e-04
# Epoch 123/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0018 - val_loss: 0.0058
# Epoch 124/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 125/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014 - val_loss: 0.0027
# Epoch 126/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 127/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016 - val_loss: 6.4789e-04
# Epoch 128/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0022 - val_loss: 0.0035
# Epoch 129/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0018 - val_loss: 8.6914e-04
# Epoch 130/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0020 - val_loss: 0.0024
# Epoch 131/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0018 - val_loss: 6.4604e-04
# Epoch 132/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 133/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 134/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - val_loss: 0.0033
# Epoch 135/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 136/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 137/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0024 - val_loss: 0.0040
# Epoch 138/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0022 - val_loss: 0.0101
# Epoch 139/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0034 - val_loss: 0.0043
# Epoch 140/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0022 - val_loss: 0.0045
# Epoch 141/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0016 - val_loss: 8.8860e-04
# Epoch 142/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 143/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0016 - val_loss: 0.0058
# Epoch 144/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0018 - val_loss: 8.7469e-04
# Epoch 145/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 146/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 147/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 148/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016 - val_loss: 0.0055
# Epoch 149/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 150/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 151/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0018 - val_loss: 0.0092
# Epoch 152/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0033 - val_loss: 6.8577e-04
# Epoch 153/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016 - val_loss: 0.0030
# Epoch 154/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - val_loss: 0.0067
# Epoch 155/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - val_loss: 0.0038
# Epoch 156/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 157/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016 - val_loss: 6.2786e-04
# Epoch 158/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0020 - val_loss: 0.0081
# Epoch 159/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 160/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 161/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 162/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0019 - val_loss: 0.0041
# Epoch 163/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 164/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014 - val_loss: 6.6526e-04
# Epoch 165/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0021 - val_loss: 0.0034
# Epoch 166/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 167/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016 - val_loss: 5.0316e-04
# Epoch 168/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 169/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0019 - val_loss: 0.0026
# Epoch 170/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0018 - val_loss: 9.6191e-04
# Epoch 171/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0023 - val_loss: 0.0012
# Epoch 172/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0015 - val_loss: 0.0029
# Epoch 173/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015 - val_loss: 9.3360e-04
# Epoch 174/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 175/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0016 - val_loss: 0.0049
# Epoch 176/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0021 - val_loss: 5.6767e-04
# Epoch 177/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - val_loss: 0.0026
# Epoch 178/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 179/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 180/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 181/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016 - val_loss: 5.0461e-04
# Epoch 182/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 183/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0016 - val_loss: 5.8169e-04
# Epoch 184/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0022 - val_loss: 6.8579e-04
# Epoch 185/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 186/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 187/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 188/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0016 - val_loss: 0.0033
# Epoch 189/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - val_loss: 0.0035
# Epoch 190/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015 - val_loss: 5.3900e-04
# Epoch 191/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014 - val_loss: 6.0505e-04
# Epoch 192/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 193/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 194/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 195/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - val_loss: 5.4642e-04
# Epoch 196/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 197/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - val_loss: 6.2933e-04
# Epoch 198/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013 - val_loss: 4.8716e-04
# Epoch 199/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0021 - val_loss: 0.0036
# Epoch 200/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016 - val_loss: 4.8824e-04

# %%
train_predict=model.predict(X_train)

test_predict=model.predict(X_test)

train_predict.shape, test_predict.shape
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# ((737, 1), (34, 1))

# %%
train_predict = scaler.inverse_transform(train_predict)

test_predict = scaler.inverse_transform(test_predict)

original_ytrain = scaler.inverse_transform(y_train.reshape(-1,1)) 

original_ytest = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
print("Train data RMSE: ", math.sqrt(mean_squared_error(original_ytrain, train_predict)))

print("Train data MSE: ", mean_squared_error(original_ytrain,train_predict))

print("Train data MAE: ", mean_absolute_error(original_ytrain,train_predict))

print("-------------------------------------------------------------------------------------")

print("Test data RMSE: ", math.sqrt(mean_squared_error(original_ytest,test_predict)))

print("Test data MSE: ", mean_squared_error(original_ytest,test_predict))

print("Test data MAE: ", mean_absolute_error(original_ytest,test_predict))
# Out:
# Train data RMSE:  2.3146057568345895
# Train data MSE:  5.357399809571823
# Train data MAE:  1.7378681374852654
# -------------------------------------------------------------------------------------
# Test data RMSE:  1.9159745908406656
# Test data MSE:  3.670958632747056
# Test data MAE:  1.5878826869967129

# %%
# Reshape test data to use as input for prediction
x_input = test_data[len(test_data) - time_step:]
x_input = (np.array(x_input)).reshape(1,time_step,-1)
print("x_input.shape ", x_input.shape)
# print("x_input", x_input)
print('###########################################################################')

from numpy import array

# Initialize variables
temp_input = list(x_input)
lst_output = []
n_steps = time_step
pred_days = 96  # Predict for 96 days

for _ in range(pred_days):
    if len(temp_input[0]) > time_step:
        x_input = array(temp_input[0][1:])  # Remove the first element from temp_input
        x_input = x_input.reshape((1, n_steps, -1))
        y_pred = model.predict(x_input, verbose=0)
        
        temp_input[0] = np.append(temp_input[0][1:], y_pred)  # Append the predicted value to temp_input
        lst_output.append(y_pred[0].tolist())
    else:
        # Reshape input for prediction if temp_input length is less than time_step
        x_input = array(temp_input[0])
        x_input = x_input.reshape((1, n_steps, -1))
        y_pred = model.predict(x_input, verbose=0)
        
        temp_input[0] = np.append(temp_input[0], y_pred)  # Append the predicted value to temp_input
        lst_output.append(y_pred[0].tolist())

print("Output of predicted next days: ", len(lst_output))
# Out:
# x_input.shape  (1, 200, 1)
# ###########################################################################
# Output of predicted next days:  96

# %%
last_days=np.arange(1,time_step+1)
day_pred=np.arange(time_step+1,time_step+pred_days+1)
temp_matrix = np.empty((len(last_days)+pred_days, 1))

temp_matrix[:] = np.nan

# %%
last_original_days_value = temp_matrix

next_predicted_days_value = temp_matrix

last_original_days_value[0:time_step] = (np.array((stock_df_close_last_1_year_original_gt.iloc[-time_step:]['Close_Company_5']))).reshape(-1,1).tolist()

# Assign values to next_predicted_days_value
next_predicted_days_value[time_step:] = (scaler.inverse_transform(lst_output)).tolist()[0]

# %%
# Convert next_predicted_days_value to a DataFrame
predictions_df = pd.DataFrame(next_predicted_days_value, columns=['Predictions5'])

# Save the DataFrame to a CSV file
predictions_df.to_csv('predictions5.csv', index=False)

# %%
# scaler is your MinMaxScaler object
# Inverse transform lst_output
new_predicted_values = scaler.inverse_transform(np.array(lst_output).reshape(-1, 1))

# Convert predicted_values to a 1D array
new_predicted_values = new_predicted_values.flatten()


# Convert next_predicted_days_value to a DataFrame
new_predictions_df = pd.DataFrame(new_predicted_values, columns=['Predictions5'])

# Save the DataFrame to a CSV file
new_predictions_df.to_csv('newpredictions5.csv', index=False)
