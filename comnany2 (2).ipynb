# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/mosaic24-ps1/sample_submission.csv
# /kaggle/input/mosaic24-ps1/train.csv
# /kaggle/input/mosaic24-ps1/test.csv

# %%
import math
import datetime as dt

from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, r2_score 
from sklearn.metrics import mean_poisson_deviance, mean_gamma_deviance, accuracy_score
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import LSTM, GRU

from itertools import cycle
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# %%
train = pd.read_csv("/kaggle/input/mosaic24-ps1/train.csv")
test = pd.read_csv("/kaggle/input/mosaic24-ps1/test.csv")

# %%
# Pivot the DataFrame
df_closing = train.pivot(index='Date', columns='Company', values=['Close'])

# Flatten the MultiIndex columns
df_closing.columns = ['_'.join(col).strip() for col in df_closing.columns.values]

# Reset index for better structure
df_closing.reset_index(inplace=True)

# Display the result
df_closing.head()
# Out:
#          Date  Close_Company_0  Close_Company_1  Close_Company_2  \
# 0  2033-03-01       161.915062       113.066659        50.094499
# 1  2033-03-05       163.108507       110.561246        49.250071
# 2  2033-03-06       161.716298       109.651386        48.878616
# 3  2033-03-07       148.051907       109.723772        48.670564
# 4  2033-03-08       148.483368       109.118052        47.642654
#
#    Close_Company_3  Close_Company_4  Close_Company_5
# 0        98.811966      8873.173069       135.882546
# 1        96.594597      8794.758109       135.970813
# 2        93.602065      8616.178598       136.070561
# 3        90.718080      8679.165970       135.772818
# 4        90.771456      8729.613528       137.854360

# %%
df_closing_company2 = df_closing[['Date', 'Close_Company_2']]

# %%
print("DataFrame for Company 2:")
print(df_closing_company2.head())
print()
# Out:
# DataFrame for Company 2:
#          Date  Close_Company_2
# 0  2033-03-01        50.094499
# 1  2033-03-05        49.250071
# 2  2033-03-06        48.878616
# 3  2033-03-07        48.670564
# 4  2033-03-08        47.642654

# %%
df_closing_company2.loc[:, 'Date'] = pd.to_datetime(df_closing_company2['Date'], utc=True)

# %%
print("Starting date: ", df_closing_company2.iloc[0, 0])
print("Ending date: ", df_closing_company2.iloc[-1, 0])
print("Duration: ", df_closing_company2.iloc[-1, 0] - df_closing_company2.iloc[0, 0])
# Out:
# Starting date:  2033-03-01 00:00:00+00:00
# Ending date:  2038-02-28 00:00:00+00:00
# Duration:  1825 days 00:00:00

# %%
from datetime import datetime
import pytz

# Convert the string to a timezone-aware Timestamp object
date_threshold_str = '2033-06-01'
date_threshold = pd.Timestamp(datetime.strptime(date_threshold_str, '%Y-%m-%d'), tz=pytz.UTC)

# Filter the DataFrame based on the condition
stock_df_close_last_1_year = df_closing_company2[df_closing_company2['Date'] > date_threshold]

# Make a copy of the filtered DataFrame
stock_df_close_last_1_year_original_gt = stock_df_close_last_1_year.copy()

# Print the total data for prediction
print("Total data for prediction: ", stock_df_close_last_1_year.shape[0])
# Out:
# Total data for prediction:  1173

# %%
fig = px.line(stock_df_close_last_1_year, x=stock_df_close_last_1_year.Date, y=stock_df_close_last_1_year.Close_Company_2,labels={'Date':'Date','Close_Company_2':'Close_Company_2'})

fig.update_traces(marker_line_width=2, opacity=0.8, marker_line_color='orange')

fig.update_layout(title_text='Considered period to predict Stock close price', plot_bgcolor='white', font_size=15, font_color='black')

fig.update_xaxes(showgrid=False)

fig.update_yaxes(showgrid=False)

fig.show()
# Out:
# <div>                            <div id="77151980-ebad-4712-9183-4f4da4d6e6c8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("77151980-ebad-4712-9183-4f4da4d6e6c8")) {                    Plotly.newPlot(                        "77151980-ebad-4712-9183-4f4da4d6e6c8",                        [{"hovertemplate":"Date=%{x}\u003cbr\u003eClose_Company_2=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle","line":{"color":"orange","width":2}},"mode":"lines","name":"","showlegend":false,"x":["2033-06-04T00:00:00+00:00","2033-06-05T00:00:00+00:00","2033-06-06T00:00:00+00:00","2033-06-07T00:00:00+00:00","2033-06-08T00:00:00+00:00","2033-06-11T00:00:00+00:00","2033-06-12T00:00:00+00:00","2033-06-13T00:00:00+00:00","2033-06-14T00:00:00+00:00","2033-06-15T00:00:00+00:00","2033-06-18T00:00:00+00:00","2033-06-19T00:00:00+00:00","2033-06-20T00:00:00+00:00","2033-06-21T00:00:00+00:00","2033-06-22T00:00:00+00:00","2033-06-25T00:00:00+00:00","2033-06-26T00:00:00+00:00","2033-06-27T00:00:00+00:00","2033-06-28T00:00:00+00:00","2033-06-29T00:00:00+00:00","2033-07-02T00:00:00+00:00","2033-07-03T00:00:00+00:00","2033-07-04T00:00:00+00:00","2033-07-05T00:00:00+00:00","2033-07-06T00:00:00+00:00","2033-07-09T00:00:00+00:00","2033-07-10T00:00:00+00:00","2033-07-11T00:00:00+00:00","2033-07-12T00:00:00+00:00","2033-07-13T00:00:00+00:00","2033-07-16T00:00:00+00:00","2033-07-17T00:00:00+00:00","2033-07-18T00:00:00+00:00","2033-07-19T00:00:00+00:00","2033-07-20T00:00:00+00:00","2033-07-23T00:00:00+00:00","2033-07-24T00:00:00+00:00","2033-07-25T00:00:00+00:00","2033-07-26T00:00:00+00:00","2033-07-27T00:00:00+00:00","2033-07-30T00:00:00+00:00","2033-07-31T00:00:00+00:00","2033-08-01T00:00:00+00:00","2033-08-02T00:00:00+00:00","2033-08-03T00:00:00+00:00","2033-08-06T00:00:00+00:00","2033-08-07T00:00:00+00:00","2033-08-08T00:00:00+00:00","2033-08-09T00:00:00+00:00","2033-08-10T00:00:00+00:00","2033-08-13T00:00:00+00:00","2033-08-14T00:00:00+00:00","2033-08-16T00:00:00+00:00","2033-08-17T00:00:00+00:00","2033-08-20T00:00:00+00:00","2033-08-21T00:00:00+00:00","2033-08-23T00:00:00+00:00","2033-08-24T00:00:00+00:00","2033-08-27T00:00:00+00:00","2033-08-28T00:00:00+00:00","2033-08-29T00:00:00+00:00","2033-08-30T00:00:00+00:00","2033-08-31T00:00:00+00:00","2033-09-03T00:00:00+00:00","2033-09-04T00:00:00+00:00","2033-09-05T00:00:00+00:00","2033-09-06T00:00:00+00:00","2033-09-07T00:00:00+00:00","2033-09-10T00:00:00+00:00","2033-09-11T00:00:00+00:00","2033-09-12T00:00:00+00:00","2033-09-14T00:00:00+00:00","2033-09-17T00:00:00+00:00","2033-09-18T00:00:00+00:00","2033-09-19T00:00:00+00:00","2033-09-21T00:00:00+00:00","2033-09-24T00:00:00+00:00","2033-09-25T00:00:00+00:00","2033-09-26T00:00:00+00:00","2033-09-27T00:00:00+00:00","2033-09-28T00:00:00+00:00","2033-10-01T00:00:00+00:00","2033-10-03T00:00:00+00:00","2033-10-04T00:00:00+00:00","2033-10-05T00:00:00+00:00","2033-10-08T00:00:00+00:00","2033-10-09T00:00:00+00:00","2033-10-10T00:00:00+00:00","2033-10-11T00:00:00+00:00","2033-10-12T00:00:00+00:00","2033-10-15T00:00:00+00:00","2033-10-16T00:00:00+00:00","2033-10-17T00:00:00+00:00","2033-10-19T00:00:00+00:00","2033-10-22T00:00:00+00:00","2033-10-23T00:00:00+00:00","2033-10-24T00:00:00+00:00","2033-10-25T00:00:00+00:00","2033-10-26T00:00:00+00:00","2033-10-29T00:00:00+00:00","2033-10-30T00:00:00+00:00","2033-10-31T00:00:00+00:00","2033-11-01T00:00:00+00:00","2033-11-02T00:00:00+00:00","2033-11-05T00:00:00+00:00","2033-11-06T00:00:00+00:00","2033-11-07T00:00:00+00:00","2033-11-09T00:00:00+00:00","2033-11-12T00:00:00+00:00","2033-11-13T00:00:00+00:00","2033-11-14T00:00:00+00:00","2033-11-15T00:00:00+00:00","2033-11-16T00:00:00+00:00","2033-11-19T00:00:00+00:00"," ...

# %%
training_size=int(len(stock_df_close_last_1_year)*0.80)

test_size=len(stock_df_close_last_1_year)-training_size

train_data,test_data = stock_df_close_last_1_year[0:training_size], stock_df_close_last_1_year[training_size:len(stock_df_close_last_1_year)]

print("train_data: ", train_data.shape)  # (201, 2)

print("test_data: ", test_data.shape)
# Out:
# train_data:  (938, 2)
# test_data:  (235, 2)

# %%
del train_data['Date']

del test_data['Date']

# %%
scaler=MinMaxScaler(feature_range=(0,1))

train_data=scaler.fit_transform(np.array(train_data).reshape(-1,1))

test_data = scaler.transform(np.array(test_data).reshape(-1,1))

print(train_data.shape)
# Out:
# (938, 1)

# %%
def create_sliding_window(dataset, time_step=200):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
time_step = 200

X_train, y_train = create_sliding_window(train_data, time_step)

X_test, y_test = create_sliding_window(test_data, time_step)

print("X_train: ", X_train.shape)
print("y_train: ", y_train.shape)
print("X_test: ", X_test.shape)
print("y_test", y_test.shape)
# Out:
# X_train:  (737, 200)
# y_train:  (737,)
# X_test:  (34, 200)
# y_test (34,)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)


print("X_train: ", X_train.shape)
print("X_test: ", X_test.shape)
# Out:
# X_train:  (737, 200, 1)
# X_test:  (34, 200, 1)

# %%
model=Sequential()

model.add(GRU(64,return_sequences=True,input_shape=(time_step,1)))

model.add(GRU(32,return_sequences=True))

model.add(GRU(32))

model.add(Dropout(0.20))

model.add(Dense(1))

model.compile(loss='mean_squared_error',optimizer='adam')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.

# %%
history = model.fit(X_train,y_train, validation_data=(X_test,y_test), epochs=300, batch_size=32, verbose=1)
# Out:
# Epoch 1/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0150 - val_loss: 6.3229e-04
# Epoch 2/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - val_loss: 0.0019
# Epoch 3/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0019 - val_loss: 3.3500e-04
# Epoch 4/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0013 - val_loss: 3.4603e-04
# Epoch 5/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0012 - val_loss: 3.7459e-04
# Epoch 6/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0015 - val_loss: 3.0792e-04
# Epoch 7/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 8/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0018 - val_loss: 3.1615e-04
# Epoch 9/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0014 - val_loss: 4.1616e-04
# Epoch 10/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0011 - val_loss: 4.0918e-04
# Epoch 11/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 9.0839e-04 - val_loss: 3.4864e-04
# Epoch 12/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 8.9127e-04 - val_loss: 6.0096e-04
# Epoch 13/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 9.4875e-04 - val_loss: 2.8276e-04
# Epoch 14/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 8.2680e-04 - val_loss: 2.7159e-04
# Epoch 15/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 9.6381e-04 - val_loss: 2.7173e-04
# Epoch 16/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 7.8908e-04 - val_loss: 2.9453e-04
# Epoch 17/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 9.3094e-04 - val_loss: 2.6691e-04
# Epoch 18/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 8.2656e-04 - val_loss: 3.1249e-04
# Epoch 19/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 8.6898e-04 - val_loss: 5.7567e-04
# Epoch 20/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0014 - val_loss: 4.5343e-04
# Epoch 21/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 8.5608e-04 - val_loss: 2.7095e-04
# Epoch 22/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.7341e-04 - val_loss: 2.9511e-04
# Epoch 23/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.9788e-04 - val_loss: 2.7466e-04
# Epoch 24/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.5361e-04 - val_loss: 4.1317e-04
# Epoch 25/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 9.7474e-04 - val_loss: 3.1119e-04
# Epoch 26/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 7.7323e-04 - val_loss: 2.9053e-04
# Epoch 27/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.5520e-04 - val_loss: 2.7706e-04
# Epoch 28/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.8110e-04 - val_loss: 2.8870e-04
# Epoch 29/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.1781e-04 - val_loss: 3.5566e-04
# Epoch 30/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0012 - val_loss: 4.8962e-04
# Epoch 31/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 9.1373e-04 - val_loss: 4.0186e-04
# Epoch 32/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0013 - val_loss: 5.3994e-04
# Epoch 33/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 7.2953e-04 - val_loss: 2.9583e-04
# Epoch 34/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.8239e-04 - val_loss: 2.8524e-04
# Epoch 35/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.5451e-04 - val_loss: 2.9924e-04
# Epoch 36/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 6.5062e-04 - val_loss: 2.9824e-04
# Epoch 37/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.9576e-04 - val_loss: 3.8242e-04
# Epoch 38/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 6.8037e-04 - val_loss: 3.0916e-04
# Epoch 39/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 7.2919e-04 - val_loss: 3.2012e-04
# Epoch 40/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.2126e-04 - val_loss: 3.4835e-04
# Epoch 41/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.9298e-04 - val_loss: 3.2055e-04
# Epoch 42/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.9924e-04 - val_loss: 3.1703e-04
# Epoch 43/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.3065e-04 - val_loss: 3.3165e-04
# Epoch 44/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.1739e-04 - val_loss: 3.2278e-04
# Epoch 45/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.6240e-04 - val_loss: 3.2532e-04
# Epoch 46/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.7030e-04 - val_loss: 3.3117e-04
# Epoch 47/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.2490e-04 - val_loss: 3.1816e-04
# Epoch 48/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.5336e-04 - val_loss: 3.1966e-04
# Epoch 49/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.6668e-04 - val_loss: 3.3884e-04
# Epoch 50/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 7.8156e-04 - val_loss: 6.8500e-04
# Epoch 51/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.6433e-04 - val_loss: 3.4507e-04
# Epoch 52/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.3611e-04 - val_loss: 4.9411e-04
# Epoch 53/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.8597e-04 - val_loss: 4.8013e-04
# Epoch 54/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.2348e-04 - val_loss: 3.8661e-04
# Epoch 55/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.4757e-04 - val_loss: 5.9101e-04
# Epoch 56/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.0071e-04 - val_loss: 3.4150e-04
# Epoch 57/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.0943e-04 - val_loss: 3.4878e-04
# Epoch 58/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.1767e-04 - val_loss: 3.9076e-04
# Epoch 59/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.7155e-04 - val_loss: 3.5592e-04
# Epoch 60/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.0453e-04 - val_loss: 3.4751e-04
# Epoch 61/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.5710e-04 - val_loss: 3.6849e-04
# Epoch 62/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.1523e-04 - val_loss: 3.4829e-04
# Epoch 63/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 8.1445e-04 - val_loss: 3.6375e-04
# Epoch 64/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.8753e-04 - val_loss: 3.6820e-04
# Epoch 65/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.5038e-04 - val_loss: 4.4151e-04
# Epoch 66/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.3467e-04 - val_loss: 5.0767e-04
# Epoch 67/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.8946e-04 - val_loss: 6.4417e-04
# Epoch 68/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.9776e-04 - val_loss: 3.6374e-04
# Epoch 69/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.9452e-04 - val_loss: 3.6807e-04
# Epoch 70/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.3408e-04 - val_loss: 4.9977e-04
# Epoch 71/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.1326e-04 - val_loss: 4.2439e-04
# Epoch 72/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.9045e-04 - val_loss: 3.8617e-04
# Epoch 73/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.2180e-04 - val_loss: 4.1111e-04
# Epoch 74/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.7413e-04 - val_loss: 3.9100e-04
# Epoch 75/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.4895e-04 - val_loss: 3.7282e-04
# Epoch 76/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.0625e-04 - val_loss: 3.7502e-04
# Epoch 77/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.6885e-04 - val_loss: 3.8946e-04
# Epoch 78/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.4912e-04 - val_loss: 3.8795e-04
# Epoch 79/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.0609e-04 - val_loss: 3.7476e-04
# Epoch 80/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.1269e-04 - val_loss: 4.5262e-04
# Epoch 81/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.5996e-04 - val_loss: 3.9713e-04
# Epoch 82/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.9812e-04 - val_loss: 3.7876e-04
# Epoch 83/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.9222e-04 - val_loss: 3.8126e-04
# Epoch 84/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.7542e-04 - val_loss: 4.8763e-04
# Epoch 85/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.9358e-04 - val_loss: 3.9575e-04
# Epoch 86/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.9724e-04 - val_loss: 3.8348e-04
# Epoch 87/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.7039e-04 - val_loss: 3.8427e-04
# Epoch 88/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.4558e-04 - val_loss: 4.0327e-04
# Epoch 89/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.8940e-04 - val_loss: 4.3320e-04
# Epoch 90/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.7253e-04 - val_loss: 4.1363e-04
# Epoch 91/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.8041e-04 - val_loss: 3.8510e-04
# Epoch 92/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.6190e-04 - val_loss: 3.8143e-04
# Epoch 93/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.6081e-04 - val_loss: 4.3237e-04
# Epoch 94/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.9772e-04 - val_loss: 3.8730e-04
# Epoch 95/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.4270e-04 - val_loss: 5.5650e-04
# Epoch 96/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.3857e-04 - val_loss: 3.9126e-04
# Epoch 97/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.1029e-04 - val_loss: 3.9137e-04
# Epoch 98/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.1406e-04 - val_loss: 3.8353e-04
# Epoch 99/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.0283e-04 - val_loss: 3.8380e-04
# Epoch 100/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.9685e-04 - val_loss: 4.6871e-04
# Epoch 101/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.7721e-04 - val_loss: 5.1945e-04
# Epoch 102/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.2038e-04 - val_loss: 4.0249e-04
# Epoch 103/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.1099e-04 - val_loss: 4.3783e-04
# Epoch 104/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.4324e-04 - val_loss: 4.9622e-04
# Epoch 105/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.6352e-04 - val_loss: 4.3754e-04
# Epoch 106/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.5512e-04 - val_loss: 3.9111e-04
# Epoch 107/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.8507e-04 - val_loss: 4.8711e-04
# Epoch 108/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.3488e-04 - val_loss: 4.7985e-04
# Epoch 109/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.3570e-04 - val_loss: 5.0791e-04
# Epoch 110/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.6063e-04 - val_loss: 6.3384e-04
# Epoch 111/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.8275e-04 - val_loss: 4.8702e-04
# Epoch 112/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.4326e-04 - val_loss: 4.0791e-04
# Epoch 113/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.4741e-04 - val_loss: 4.2872e-04
# Epoch 114/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.4209e-04 - val_loss: 5.2243e-04
# Epoch 115/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.0526e-04 - val_loss: 6.3442e-04
# Epoch 116/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.2361e-04 - val_loss: 5.3690e-04
# Epoch 117/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.8720e-04 - val_loss: 5.4119e-04
# Epoch 118/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 8.9190e-04 - val_loss: 4.9028e-04
# Epoch 119/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.0977e-04 - val_loss: 4.6307e-04
# Epoch 120/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.6257e-04 - val_loss: 4.2567e-04
# Epoch 121/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.1607e-04 - val_loss: 4.7274e-04
# Epoch 122/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.5017e-04 - val_loss: 4.5621e-04
# Epoch 123/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.0006e-04 - val_loss: 4.4142e-04
# Epoch 124/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.5762e-04 - val_loss: 4.1561e-04
# Epoch 125/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.5394e-04 - val_loss: 4.2743e-04
# Epoch 126/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.6755e-04 - val_loss: 5.3425e-04
# Epoch 127/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.8798e-04 - val_loss: 4.6532e-04
# Epoch 128/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.6575e-04 - val_loss: 4.5369e-04
# Epoch 129/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.8932e-04 - val_loss: 6.5245e-04
# Epoch 130/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.6126e-04 - val_loss: 3.9961e-04
# Epoch 131/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.9622e-04 - val_loss: 4.0572e-04
# Epoch 132/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.1306e-04 - val_loss: 5.8893e-04
# Epoch 133/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.8711e-04 - val_loss: 4.7490e-04
# Epoch 134/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.9455e-04 - val_loss: 4.8080e-04
# Epoch 135/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.3704e-04 - val_loss: 5.0491e-04
# Epoch 136/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.6775e-04 - val_loss: 4.5208e-04
# Epoch 137/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.9249e-04 - val_loss: 4.5179e-04
# Epoch 138/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.6429e-04 - val_loss: 4.1650e-04
# Epoch 139/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.4299e-04 - val_loss: 4.1019e-04
# Epoch 140/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.6095e-04 - val_loss: 5.0668e-04
# Epoch 141/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.9689e-04 - val_loss: 4.1038e-04
# Epoch 142/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.8189e-04 - val_loss: 4.2587e-04
# Epoch 143/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.9471e-04 - val_loss: 4.6438e-04
# Epoch 144/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.3215e-04 - val_loss: 4.7189e-04
# Epoch 145/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.3582e-04 - val_loss: 4.0313e-04
# Epoch 146/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.9559e-04 - val_loss: 4.2524e-04
# Epoch 147/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.7220e-04 - val_loss: 4.0392e-04
# Epoch 148/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.5840e-04 - val_loss: 3.9835e-04
# Epoch 149/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.0477e-04 - val_loss: 4.1588e-04
# Epoch 150/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.9699e-04 - val_loss: 4.1882e-04
# Epoch 151/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.6011e-04 - val_loss: 4.2618e-04
# Epoch 152/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.8769e-04 - val_loss: 3.9629e-04
# Epoch 153/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.1379e-04 - val_loss: 4.0689e-04
# Epoch 154/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.9032e-04 - val_loss: 4.1069e-04
# Epoch 155/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.1920e-04 - val_loss: 4.0415e-04
# Epoch 156/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.1121e-04 - val_loss: 7.0683e-04
# Epoch 157/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.3193e-04 - val_loss: 4.4666e-04
# Epoch 158/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.0641e-04 - val_loss: 4.3074e-04
# Epoch 159/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.2683e-04 - val_loss: 4.4357e-04
# Epoch 160/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.0362e-04 - val_loss: 4.2635e-04
# Epoch 161/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.8124e-04 - val_loss: 5.3106e-04
# Epoch 162/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.7144e-04 - val_loss: 4.1075e-04
# Epoch 163/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.0284e-04 - val_loss: 4.9275e-04
# Epoch 164/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.9153e-04 - val_loss: 4.0626e-04
# Epoch 165/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.5578e-04 - val_loss: 4.0824e-04
# Epoch 166/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.7145e-04 - val_loss: 4.5384e-04
# Epoch 167/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.8539e-04 - val_loss: 5.8563e-04
# Epoch 168/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.7440e-04 - val_loss: 3.9950e-04
# Epoch 169/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.3885e-04 - val_loss: 3.9412e-04
# Epoch 170/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 7.0577e-04 - val_loss: 4.0725e-04
# Epoch 171/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.5124e-04 - val_loss: 4.8948e-04
# Epoch 172/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.6827e-04 - val_loss: 3.9990e-04
# Epoch 173/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.7131e-04 - val_loss: 4.2542e-04
# Epoch 174/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.5596e-04 - val_loss: 3.9319e-04
# Epoch 175/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.6753e-04 - val_loss: 4.5351e-04
# Epoch 176/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.6963e-04 - val_loss: 4.1348e-04
# Epoch 177/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.0733e-04 - val_loss: 4.1692e-04
# Epoch 178/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.8535e-04 - val_loss: 4.4488e-04
# Epoch 179/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.5286e-04 - val_loss: 4.0793e-04
# Epoch 180/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.9287e-04 - val_loss: 4.4592e-04
# Epoch 181/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.9327e-04 - val_loss: 4.1508e-04
# Epoch 182/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.6059e-04 - val_loss: 4.3409e-04
# Epoch 183/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.9524e-04 - val_loss: 4.0105e-04
# Epoch 184/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.5188e-04 - val_loss: 4.5679e-04
# Epoch 185/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.9448e-04 - val_loss: 4.2346e-04
# Epoch 186/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 7.6516e-04 - val_loss: 4.4127e-04
# Epoch 187/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.3817e-04 - val_loss: 4.0330e-04
# Epoch 188/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.0588e-04 - val_loss: 4.6508e-04
# Epoch 189/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.9264e-04 - val_loss: 4.2839e-04
# Epoch 190/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.7267e-04 - val_loss: 4.1583e-04
# Epoch 191/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.9789e-04 - val_loss: 4.1624e-04
# Epoch 192/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.2771e-04 - val_loss: 6.5465e-04
# Epoch 193/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.1594e-04 - val_loss: 4.0836e-04
# Epoch 194/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.0206e-04 - val_loss: 4.1653e-04
# Epoch 195/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.8965e-04 - val_loss: 4.1767e-04
# Epoch 196/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.4252e-04 - val_loss: 4.4269e-04
# Epoch 197/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.9152e-04 - val_loss: 4.4183e-04
# Epoch 198/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.7923e-04 - val_loss: 4.6857e-04
# Epoch 199/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.0886e-04 - val_loss: 5.0230e-04
# Epoch 200/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.2879e-04 - val_loss: 4.2150e-04
# Epoch 201/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.7076e-04 - val_loss: 4.2954e-04
# Epoch 202/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.6586e-04 - val_loss: 4.1658e-04
# Epoch 203/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.1923e-04 - val_loss: 4.1576e-04
# Epoch 204/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.6748e-04 - val_loss: 4.9503e-04
# Epoch 205/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.5955e-04 - val_loss: 4.6282e-04
# Epoch 206/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.7166e-04 - val_loss: 4.2040e-04
# Epoch 207/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.9831e-04 - val_loss: 4.0444e-04
# Epoch 208/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.6692e-04 - val_loss: 7.2500e-04
# Epoch 209/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0011 - val_loss: 4.5155e-04
# Epoch 210/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.4245e-04 - val_loss: 4.5406e-04
# Epoch 211/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.6659e-04 - val_loss: 4.4190e-04
# Epoch 212/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.1674e-04 - val_loss: 4.3878e-04
# Epoch 213/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.3848e-04 - val_loss: 4.4295e-04
# Epoch 214/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.7677e-04 - val_loss: 4.8985e-04
# Epoch 215/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.6315e-04 - val_loss: 4.2323e-04
# Epoch 216/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.6631e-04 - val_loss: 4.2131e-04
# Epoch 217/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.2461e-04 - val_loss: 4.3965e-04
# Epoch 218/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.0174e-04 - val_loss: 4.4275e-04
# Epoch 219/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.7673e-04 - val_loss: 4.1590e-04
# Epoch 220/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.6387e-04 - val_loss: 4.8204e-04
# Epoch 221/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.5711e-04 - val_loss: 4.4013e-04
# Epoch 222/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.5883e-04 - val_loss: 4.3209e-04
# Epoch 223/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.3369e-04 - val_loss: 4.8128e-04
# Epoch 224/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.3501e-04 - val_loss: 4.2103e-04
# Epoch 225/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.2965e-04 - val_loss: 4.0609e-04
# Epoch 226/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.4172e-04 - val_loss: 4.5459e-04
# Epoch 227/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.1065e-04 - val_loss: 5.0951e-04
# Epoch 228/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.5451e-04 - val_loss: 4.0281e-04
# Epoch 229/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.1851e-04 - val_loss: 4.6361e-04
# Epoch 230/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.5300e-04 - val_loss: 4.2527e-04
# Epoch 231/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.2695e-04 - val_loss: 3.9963e-04
# Epoch 232/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.0289e-04 - val_loss: 4.0307e-04
# Epoch 233/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.9308e-04 - val_loss: 3.9769e-04
# Epoch 234/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.0223e-04 - val_loss: 4.9628e-04
# Epoch 235/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.0142e-04 - val_loss: 4.0666e-04
# Epoch 236/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.6023e-04 - val_loss: 4.6983e-04
# Epoch 237/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.8290e-04 - val_loss: 5.6493e-04
# Epoch 238/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.7851e-04 - val_loss: 4.2696e-04
# Epoch 239/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.4705e-04 - val_loss: 4.2104e-04
# Epoch 240/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.3840e-04 - val_loss: 4.8023e-04
# Epoch 241/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.2363e-04 - val_loss: 4.1568e-04
# Epoch 242/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.2920e-04 - val_loss: 4.2301e-04
# Epoch 243/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.7013e-04 - val_loss: 4.2549e-04
# Epoch 244/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.9748e-04 - val_loss: 6.2156e-04
# Epoch 245/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.2852e-04 - val_loss: 5.0457e-04
# Epoch 246/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.9437e-04 - val_loss: 4.7150e-04
# Epoch 247/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.3494e-04 - val_loss: 4.1393e-04
# Epoch 248/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.9161e-04 - val_loss: 4.1983e-04
# Epoch 249/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.0455e-04 - val_loss: 5.0159e-04
# Epoch 250/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 6.6796e-04 - val_loss: 4.5711e-04
# Epoch 251/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.3279e-04 - val_loss: 4.1557e-04
# Epoch 252/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.1867e-04 - val_loss: 4.0620e-04
# Epoch 253/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.2952e-04 - val_loss: 4.2685e-04
# Epoch 254/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.5876e-04 - val_loss: 7.9541e-04
# Epoch 255/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.5619e-04 - val_loss: 4.2160e-04
# Epoch 256/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.9423e-04 - val_loss: 4.0921e-04
# Epoch 257/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.8002e-04 - val_loss: 4.2482e-04
# Epoch 258/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.3274e-04 - val_loss: 4.8364e-04
# Epoch 259/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.7388e-04 - val_loss: 4.0480e-04
# Epoch 260/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.4215e-04 - val_loss: 4.9772e-04
# Epoch 261/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.9297e-04 - val_loss: 4.8217e-04
# Epoch 262/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.8061e-04 - val_loss: 4.0153e-04
# Epoch 263/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.3707e-04 - val_loss: 4.6067e-04
# Epoch 264/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.9614e-04 - val_loss: 4.0982e-04
# Epoch 265/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.0617e-04 - val_loss: 5.0280e-04
# Epoch 266/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.6600e-04 - val_loss: 4.3445e-04
# Epoch 267/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.9620e-04 - val_loss: 6.0533e-04
# Epoch 268/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.0860e-04 - val_loss: 5.1562e-04
# Epoch 269/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.1202e-04 - val_loss: 4.1355e-04
# Epoch 270/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.1039e-04 - val_loss: 4.3538e-04
# Epoch 271/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.3583e-04 - val_loss: 4.4567e-04
# Epoch 272/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.0484e-04 - val_loss: 4.1551e-04
# Epoch 273/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.1468e-04 - val_loss: 4.3950e-04
# Epoch 274/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.6840e-04 - val_loss: 4.3913e-04
# Epoch 275/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.1025e-04 - val_loss: 4.2612e-04
# Epoch 276/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.9340e-04 - val_loss: 4.5875e-04
# Epoch 277/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.0233e-04 - val_loss: 4.2815e-04
# Epoch 278/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.3190e-04 - val_loss: 4.3507e-04
# Epoch 279/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.6821e-04 - val_loss: 4.2218e-04
# Epoch 280/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.7422e-04 - val_loss: 4.2069e-04
# Epoch 281/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.6409e-04 - val_loss: 4.5234e-04
# Epoch 282/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.1752e-04 - val_loss: 4.5618e-04
# Epoch 283/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.3582e-04 - val_loss: 4.3252e-04
# Epoch 284/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.3544e-04 - val_loss: 5.4164e-04
# Epoch 285/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 7.2290e-04 - val_loss: 4.2329e-04
# Epoch 286/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.1159e-04 - val_loss: 4.5178e-04
# Epoch 287/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.9058e-04 - val_loss: 4.1641e-04
# Epoch 288/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.4220e-04 - val_loss: 4.1333e-04
# Epoch 289/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.2806e-04 - val_loss: 4.1216e-04
# Epoch 290/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.0267e-04 - val_loss: 4.1720e-04
# Epoch 291/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.5867e-04 - val_loss: 4.1380e-04
# Epoch 292/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.5629e-04 - val_loss: 4.0658e-04
# Epoch 293/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.6496e-04 - val_loss: 4.0835e-04
# Epoch 294/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.3102e-04 - val_loss: 4.1300e-04
# Epoch 295/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.0079e-04 - val_loss: 4.0598e-04
# Epoch 296/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.5457e-04 - val_loss: 4.6912e-04
# Epoch 297/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.4570e-04 - val_loss: 4.4696e-04
# Epoch 298/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.9517e-04 - val_loss: 4.4749e-04
# Epoch 299/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.2915e-04 - val_loss: 7.1648e-04
# Epoch 300/300
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 8.2655e-04 - val_loss: 4.4032e-04

# %%
train_predict=model.predict(X_train)

test_predict=model.predict(X_test)

train_predict.shape, test_predict.shape
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# ((737, 1), (34, 1))

# %%
train_predict = scaler.inverse_transform(train_predict)

test_predict = scaler.inverse_transform(test_predict)

original_ytrain = scaler.inverse_transform(y_train.reshape(-1,1)) 

original_ytest = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
print("Train data RMSE: ", math.sqrt(mean_squared_error(original_ytrain, train_predict)))

print("Train data MSE: ", mean_squared_error(original_ytrain,train_predict))

print("Train data MAE: ", mean_absolute_error(original_ytrain,train_predict))

print("-------------------------------------------------------------------------------------")

print("Test data RMSE: ", math.sqrt(mean_squared_error(original_ytest,test_predict)))

print("Test data MSE: ", mean_squared_error(original_ytest,test_predict))

print("Test data MAE: ", mean_absolute_error(original_ytest,test_predict))
# Out:
# Train data RMSE:  0.7563874835882625
# Train data MSE:  0.572122025328984
# Train data MAE:  0.5828980712868959
# -------------------------------------------------------------------------------------
# Test data RMSE:  0.7256770242041648
# Test data MSE:  0.526607143457812
# Test data MAE:  0.5741732731265965

# %%
# Reshape test data to use as input for prediction
x_input = test_data[len(test_data) - time_step:]
x_input = (np.array(x_input)).reshape(1,time_step,-1)
print("x_input.shape ", x_input.shape)
# print("x_input", x_input)
print('###########################################################################')

from numpy import array

# Initialize variables
temp_input = list(x_input)
lst_output = []
n_steps = time_step
pred_days = 96  # Predict for 96 days

for _ in range(pred_days):
    if len(temp_input[0]) > time_step:
        x_input = array(temp_input[0][1:])  # Remove the first element from temp_input
        x_input = x_input.reshape((1, n_steps, -1))
        y_pred = model.predict(x_input, verbose=0)
        
        temp_input[0] = np.append(temp_input[0][1:], y_pred)  # Append the predicted value to temp_input
        lst_output.append(y_pred[0].tolist())
    else:
        # Reshape input for prediction if temp_input length is less than time_step
        x_input = array(temp_input[0])
        x_input = x_input.reshape((1, n_steps, -1))
        y_pred = model.predict(x_input, verbose=0)
        
        temp_input[0] = np.append(temp_input[0], y_pred)  # Append the predicted value to temp_input
        lst_output.append(y_pred[0].tolist())

print("Output of predicted next days: ", len(lst_output))
# Out:
# x_input.shape  (1, 200, 1)
# ###########################################################################
# Output of predicted next days:  96

# %%
last_days=np.arange(1,time_step+1)
day_pred=np.arange(time_step+1,time_step+pred_days+1)

# %%
temp_matrix = np.empty((len(last_days)+pred_days, 1))

temp_matrix[:] = np.nan

# %%
stock_df_close_last_1_year_original_gt.iloc[-time_step:]['Close_Company_2'].shape
# Out:
# (200,)

# %%
last_original_days_value = temp_matrix

next_predicted_days_value = temp_matrix

last_original_days_value[0:time_step] = (np.array((stock_df_close_last_1_year_original_gt.iloc[-time_step:]['Close_Company_2']))).reshape(-1,1).tolist()

# Assign values to next_predicted_days_value
next_predicted_days_value[time_step:] = (scaler.inverse_transform(lst_output)).tolist()[0]

# %%
# next_predicted_days_value

# %%
predictions_df = pd.DataFrame(next_predicted_days_value, columns=['Predictions'])

# Generate IDs starting from 2 with an increment of +6
ids = list(range(2, len(predictions_df) * 6 + 2, 6))

# Add the IDs as a new column
predictions_df['Id'] = ids


# Save the DataFrame to a CSV file
predictions_df.to_csv('predictions02.csv', index=False)

# %%
# scaler is your MinMaxScaler object
# Inverse transform lst_output
new_predicted_values = scaler.inverse_transform(np.array(lst_output).reshape(-1, 1))

# Convert predicted_values to a 1D array
new_predicted_values = new_predicted_values.flatten()


# Convert next_predicted_days_value to a DataFrame
new_predictions_df = pd.DataFrame(new_predicted_values, columns=['Predictions2'])

# Save the DataFrame to a CSV file
new_predictions_df.to_csv('newpredictions2.csv', index=False)
